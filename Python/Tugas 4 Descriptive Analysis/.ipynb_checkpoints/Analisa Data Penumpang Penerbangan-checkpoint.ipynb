# %% [markdown]
# # Analisa Data Penumpang Penerbangan
#
# Temukan data yang menurut kalian menarik pada http://data.go.id . Buat analisa data yang berisi:
# 1. Deskripsi data
# 2. Statistik tentang data
# 3. Visualisasi sederhana
# 4. Narasi analisis
#
# ------
# ## Descriptive Analysis Airlines Pessenger
# *Mukti Setyaji* <br>
# *23-Oct-2018*
#
# * **1. Introduction**
#     * 1.1 Dataset
#     * 1.2 Objective
# * **2. Data Exploration**
# * **3. Basic Statistic**
# * **4. Data Visualization***
# * **5. Conclusion**
# * **6. Future Work**

# %% [markdown]
# ### 1. Introduction
# #### 1.1 Dataset
# [The Dataset](https://data.go.id/dataset/jumlah-penumpang-yang-berangkat-pada-penerbangan-domestik) we used are about the total of airlines pessenger in Indonesia (nationaly). It has three feature:
# 1. Tahun
# 2. Bulan
# 3. Total_Pessenger
# 4. Airport

# %% [markdown]
# #### 1.2 Objective
# 1. What was the total pessenger from 2006 to august 2018?
# 2. What airport
# 3. ?

# %% [markdown]
# ### 2. Data Exploration

# %%
# import every package that we're going to use
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="darkgrid")
color = sns.color_palette()

# check what inside folder
os.listdir("./data/airline")
# Out:
# ['jumlah-penumpang-penerbangan-internasional.csv',
#  'info',
#  'produksi-perusahaan-penerbangan-luar-negeri.csv',
#  'jumlah-penumpang-penerbangan-domestik.csv',
#  'produksi-perusahaan-penerbangan-dalam-negeri.csv']

# %%
# Store path
dataset = "./data/airline/jumlah-penumpang-penerbangan-domestik.csv"

# Create Dataframe
df = pd.read_csv(dataset, delimiter=';')

# Check dataframe information
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 6 columns):
# nama_variabel                  760 non-null object
# nama_variabel_turunan          760 non-null object
# nama_tahun                     760 non-null int64
# nama_turunan_tahun             760 non-null object
# data_content                   760 non-null int64
# nama_item_vertical_variabel    760 non-null object
# dtypes: int64(2), object(4)
# memory usage: 35.7+ KB
# None

# %% [markdown]
# There is something wrong here. Before jumping to a conclusion we're going to check the data.

# %%
print (df.sample(5))
# Out:
#                                  nama_variabel  \
# 728  Jumlah Penumpang Pesawat di Bandara Utama
# 126  Jumlah Penumpang Pesawat di Bandara Utama
# 631  Jumlah Penumpang Pesawat di Bandara Utama
# 392  Jumlah Penumpang Pesawat di Bandara Utama
# 736  Jumlah Penumpang Pesawat di Bandara Utama
#
#                        nama_variabel_turunan  nama_tahun nama_turunan_tahun  \
# 728  Keberangkatan pada Penerbangan Domestik        2018           Februari
# 126  Keberangkatan pada Penerbangan Domestik        2008           Februari
# 631  Keberangkatan pada Penerbangan Domestik        2016               Juli
# 392  Keberangkatan pada Penerbangan Domestik        2012               Juli
# 736  Keberangkatan pada Penerbangan Domestik        2018              April
#
#      data_content nama_item_vertical_variabel
# 728        401856                  Ngurah Rai
# 126        928984              Soekarno Hatta
# 631       1940711              Soekarno Hatta
# 392        602625                      Juanda
# 736       1949487              Soekarno Hatta

# %% [markdown]
# There is a column that we don't need here: "nama_variabel" and "nama_variabel_turunan".<br>

# %%
df = df.drop(columns="nama_variabel")
df = df.drop(columns="nama_variabel_turunan")
print (df.sample(5))
# Out:
#      nama_tahun nama_turunan_tahun  data_content nama_item_vertical_variabel
# 542        2015            Januari        565027                      Juanda
# 34         2006               Juli        141863                   Hasanudin
# 569        2015               Juni        261900                   Hasanudin
# 446        2013               Juni       1854812              Soekarno Hatta
# 20         2006                Mei        147322                     Polonia

# %% [markdown]
# We need to change the column name so its readable.

# %%
df.columns = ["tahun", "bulan", "jumlah_penumpang", "bandara"]

print (df.sample(5))
# Out:
#      tahun      bulan  jumlah_penumpang         bandara
# 466   2013    Oktober           1816513  Soekarno Hatta
# 643   2016  September            431540      Ngurah Rai
# 250   2010      Maret            196749         Polonia
# 556   2015      April           1492524  Soekarno Hatta
# 622   2016        Mei            675702          Juanda

# %% [markdown]
# We need to check is there any noise or not in data.

# %%
M = {"Januari": 1, 
     "Februari": 2,
     "Maret": 3,
     "April": 4,
     "Mei": 5,
     "Juni": 6,
     "Juli": 7,
     "Agustus": 8,
     "September": 9,
     "Oktober": 10,
     "November": 11,
     "Desember": 12}

MT = {}
mt = []
for m, n in M.items():
    MT[n] = m
    mt.append(m)

df.bulan = df.bulan.map(M)

# %%
pd.to_datetime(df.bulan, format='%m').dt.month
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# 5      2
# 6      2
# 7      2
# 8      2
# 9      2
# 10     3
# 11     3
# 12     3
# 13     3
# 14     3
# 15     4
# 16     4
# 17     4
# 18     4
# 19     4
# 20     5
# 21     5
# 22     5
# 23     5
# 24     5
# 25     6
# 26     6
# 27     6
# 28     6
# 29     6
#       ..
# 730    3
# 731    3
# 732    3
# 733    3
# 734    3
# 735    4
# 736    4
# 737    4
# 738    4
# 739    4
# 740    5
# 741    5
# 742    5
# 743    5
# 744    5
# 745    6
# 746    6
# 747    6
# 748    6
# 749    6
# 750    7
# 751    7
# 752    7
# 753    7
# 754    7
# 755    8
# 756    8
# 757    8
# 758    8
# 759    8
# Name: bulan, Length: 760, dtype: int64

# %%
# Check noise
print (df.isnull().sum().sort_values())
# Out:
# tahun               0
# bulan               0
# jumlah_penumpang    0
# bandara             0
# dtype: int64

# %%
print (df[df["jumlah_penumpang"] == 0])
# Out:
# Empty DataFrame
# Columns: [tahun, bulan, jumlah_penumpang, bandara]
# Index: []

# %% [markdown]
# Now, we're going to see the 10 list from top and bottom.

# %%
print (df.head(10))
# Out:
#    tahun  bulan  jumlah_penumpang         bandara
# 0   2006      1            169652         Polonia
# 1   2006      1           1005200  Soekarno Hatta
# 2   2006      1            329764          Juanda
# 3   2006      1            136457      Ngurah Rai
# 4   2006      1            109646       Hasanudin
# 5   2006      2            138623         Polonia
# 6   2006      2            723717  Soekarno Hatta
# 7   2006      2            257149          Juanda
# 8   2006      2            107825      Ngurah Rai
# 9   2006      2             93528       Hasanudin

# %%
print (df.tail(10))
# Out:
#      tahun  bulan  jumlah_penumpang         bandara
# 750   2018      7            361523         Polonia
# 751   2018      7           2132360  Soekarno Hatta
# 752   2018      7            856010          Juanda
# 753   2018      7            546118      Ngurah Rai
# 754   2018      7            431134       Hasanudin
# 755   2018      8            317360         Polonia
# 756   2018      8           1932013  Soekarno Hatta
# 757   2018      8            720669          Juanda
# 758   2018      8            509666      Ngurah Rai
# 759   2018      8            361565       Hasanudin

# %%
easy_df = df.groupby(["tahun", "bulan", "bandara"]).sum()
print (easy_df.head(10))
# Out:
#                             jumlah_penumpang
# tahun bulan bandara
# 2006  1     Hasanudin                 109646
#             Juanda                    329764
#             Ngurah Rai                136457
#             Polonia                   169652
#             Soekarno Hatta           1005200
#       2     Hasanudin                  93528
#             Juanda                    257149
#             Ngurah Rai                107825
#             Polonia                   138623
#             Soekarno Hatta            723717

# %% [markdown]
# ### 3. Basic Statistic

# %%
pessenger_growth_in_year = df.groupby("tahun").sum()
print (pessenger_growth_in_year)
# Out:
#        bulan  jumlah_penumpang
# tahun
# 2006     390          19352551
# 2007     390          21092617
# 2008     390          21016141
# 2009     390          23755956
# 2010     390          28033773
# 2011     390          32297644
# 2012     390          36431328
# 2013     390          38812708
# 2014     390          38051273
# 2015     390          36644324
# 2016     390          41094610
# 2017     390          42780122
# 2018     180          29846092

# %%
#pessenger_growth_in_month = df.groupby(["tahun", "bulan"]).sum()
pessenger_growth_in_month = pd.pivot_table(df, values="jumlah_penumpang", index=["bulan"], columns=["tahun"], aggfunc=np.sum)

print (pessenger_growth_in_month)
# Out:
# tahun      2006      2007      2008      2009      2010      2011      2012  \
# bulan
# 1     1,750,719 1,616,458 1,885,122 1,805,469 2,156,030 2,552,852 2,939,664
# 2     1,320,842 1,214,719 1,657,430 1,598,861 1,947,299 2,305,103 2,660,244
# 3     1,494,624 1,496,160 1,840,429 1,874,506 2,138,945 2,508,704 2,956,851
# 4     1,567,581 1,816,134 1,636,647 1,730,277 2,196,266 2,477,465 2,893,357
# 5     1,544,567 1,723,827 1,717,530 2,014,524 2,327,565 2,573,053 3,019,090
# 6     1,580,139 1,752,591 1,720,834 2,039,443 2,372,943 2,910,025 3,066,628
# 7     1,839,908 2,033,904 1,902,375 2,220,124 2,648,481 3,051,533 3,153,219
# 8     1,713,851 1,905,218 1,850,865 2,019,504 2,115,276 2,428,291 2,963,430
# 9     1,579,539 1,619,928 1,375,451 1,840,816 2,439,281 2,909,316 3,201,962
# 10    1,463,691 1,996,695 1,837,525 2,254,197 2,561,100 2,769,437 3,152,060
# 11    1,713,597 1,913,936 1,716,316 2,133,607 2,407,455 2,861,276 3,180,629
# 12    1,783,493 2,003,047 1,875,617 2,224,628 2,723,132 2,950,589 3,244,194
#
# tahun      2013      2014      2015      2016      2017      2018
# bulan
# 1     3,082,469 3,277,897 2,957,642 3,420,209 3,513,225 3,632,529
# 2     2,728,255 2,584,272 2,536,773 3,024,606 2,919,674 3,298,422
# 3     3,154,718 3,037,513 2,800,216 3,286,597 3,361,499 3,676,658
# 4     3,015,745 2,816,409 2,822,228 3,199,558 3,454,991 3,771,562
# 5     3,225,435 3,306,419 3,147,098 3,638,541 3,501,387 3,399,461
# 6     3,475,200 3,390,296 2,961,317 3,005,795 3,296,844 3,899,042
# 7     2,990,298 2,839,945 3,413,583 4,053,538 4,368,227 4,327,145
# 8     3,519,542 3,574,480 3,494,916 3,629,214 3,722,676 3,841,273
# 9     3,331,164 3,134,642 2,842,902 3,323,167 3,608,873       nan
# 10    3,424,595 3,358,282 3,121,429 3,422,810 3,574,010       nan
# 11    3,284,147 3,218,060 3,095,079 3,337,665 3,534,496       nan
# 12    3,581,140 3,513,058 3,451,141 3,752,910 3,924,220       nan

# %%
most_used_airport = df.groupby("bandara").sum()
print (most_used_airport)
# Out:
#                  tahun  bulan  jumlah_penumpang
# bandara
# Hasanudin       305800    972          35296795
# Juanda          305800    972          75022458
# Ngurah Rai      305800    972          44248564
# Polonia         305800    972          35929724
# Soekarno Hatta  305800    972         218711598

# %% [markdown]
# ### 4. Data Visualization

# %%
plt.figure(figsize=(12, 6))

ax = plt.subplot(1, 2, 1)
pessenger_growth_in_year.plot(kind="line", ax = ax)
plt.title("Pessenger Growth in Year (2006 - August 2018)")

ax = plt.subplot(1, 2, 2)
pessenger_growth_in_year.plot(kind="bar", ax = ax)
plt.title("Pessenger Growth in Year (2006 - August 2018)")
# Out:
# Text(0.5, 1.0, 'Pessenger Growth in Year (2006 - August 2018)')

# %%
most_used_airport.plot(kind="bar")
plt.title("Total Pessenger in Airport")
# Out:
# Text(0.5, 1.0, 'Total Pessenger in Airport')

# %%
plt.figure(figsize=(12, 6))
ay = plt.subplot(1, 1, 1)

pessenger_growth_in_month.plot(ax = ay)

# %%
az = plt.subplot(13, 2, 1)
pessenger_growth_in_month[2006].plot(ax=az)
az = plt.subplot(13, 2, 2)
pessenger_growth_in_month[2006].plot(kind="bar", ax=az)

# %% [markdown]
# ### 5. Descriptive Analysis

# %% [markdown]
# ### 6. Future Work
